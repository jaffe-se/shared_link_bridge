# %%
import socket
import threading

# TESTING_HOSTNAME = 'localhost'
# TESTING_PORT = 12000

BUFFER_SIZE = 4096

# %%
def default_on_recv(data_raw, addr):
    data = data_raw.decode()
    
    print(f"From: {addr[0]} / {addr[1]}")
    print(f"Data: {data}")

# def udp_stream(host, port, on_recv=default_on_recv, buffer_size=4096, timeout=1.0):
#     """
#     Receives UDP packets and calls on_frame(data) for each valid JPEG frame.
#     Returns a stop function — call it to end the stream.
#     """
#     stop_event = threading.Event()
#     sock = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
#     sock.bind((host, port))
#     sock.settimeout(timeout)

#     def loop():
#         while not stop_event.is_set():
#             try:
#                 data, addr = sock.recvfrom(buffer_size)
#                 on_recv(data, addr)
#             except socket.timeout:
#                 continue
#         sock.close()

#     thread = threading.Thread(target=loop, daemon=True)
#     thread.start()

#     return stop_event.set  # caller gets back just the stop function

class UDPStream:
    def __init__(self, port: int, dest_host: str = "", on_recv: callable = default_on_recv, buffer_size: int = 4096, timeout: float = 1.0):
        self._stop_event = threading.Event()
        self._sock = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
        self._sock.bind(('', port))
        self._sock.settimeout(timeout)

        self._default_dest_host = dest_host
        self._port = port
        self._buffer_size = buffer_size
        self._on_recv = on_recv

        thread = threading.Thread(target=self._loop, daemon=True)
        thread.start()

    def __del__(self):
        self.stop()

    def _loop(self):
        while not self._stop_event.is_set():
            try:
                data, addr = self._sock.recvfrom(self._buffer_size)
                self._on_recv(data, addr)
            except socket.timeout:
                continue
        self._sock.close()

    def send(self, data, host=None):
        if host is None: host = self._default_dest_host
        self._sock.sendto(data, (host, self._port))

    def stop(self):
        self._stop_event.set()

# %%
import ipywidgets as widgets
from IPython.display import display

img_widget = widgets.Image(format='jpeg')
img_widget.layout.width = '10%' 
display(img_widget)

SERVER_PORT = 1901

def on_recv_broadcast(data_raw, addr):
    print(data_raw[1:4])
    if data_raw[1:4] == b'\xff\xd8\xff':
        setattr(img_widget, 'value', data_raw[1:])
    else:
        data = data_raw.decode()
        print(data)
    
    print(f"From: {addr[0]} / {addr[1]}")

broadcast_listener = UDPStream(SERVER_PORT, on_recv=on_recv_broadcast, buffer_size=10000)
# Out:
# Image(value=b'', format='jpeg', layout="Layout(width='10%')")
# b'|SN'
# ||SN23030555|192.168.200.220|VEH_NorthEastern1|Vehicle_SH/SL/IVN/DWB|djBasis.exe, djJAUS_IVN.exe, djEtherMap.exe, DJ_LDR.EXE, djSharedLinkF.exe, GPS2RDDF.EXE, djMimic.exe, djPinger.exe, djDriveWB.exe|0|0|0|0|||01-01-2012|00:00:34|SharedLink,192.168.200.220:4000:4220;Cmd: Restart System,restart djBasis,7101;Cmd: Guideline dist,follow #,7101||
# From: 192.168.200.220 / 1901
# b'\xff\xd8\xff'
# From: 192.168.200.220 / 1901
# b'|SN'
# ||SN23030555|192.168.200.220|VEH_NorthEastern1|Vehicle_SH/SL/IVN/DWB|djBasis.exe, djJAUS_IVN.exe, djEtherMap.exe, DJ_LDR.EXE, djSharedLinkF.exe, GPS2RDDF.EXE, djMimic.exe, djPinger.exe, djDriveWB.exe|0|0|0|0|||01-01-2012|00:00:34|SharedLink,192.168.200.220:4000:4220;Cmd: Restart System,restart djBasis,7101;Cmd: Guideline dist,follow #,7101||
# From: 192.168.200.220 / 1901
# b'\xff\xd8\xff'
# From: 192.168.200.220 / 1901
# b'|SN'
# ||SN23030555|192.168.200.220|VEH_NorthEastern1|Vehicle_SH/SL/IVN/DWB|djBasis.exe, djJAUS_IVN.exe, djEtherMap.exe, DJ_LDR.EXE, djSharedLinkF.exe, GPS2RDDF.EXE, djMimic.exe, djPinger.exe, djDriveWB.exe|0|0|0|0|||01-01-2012|00:00:34|SharedLink,192.168.200.220:4000:4220;Cmd: Restart System,restart djBasis,7101;Cmd: Guideline dist,follow #,7101||
# From: 192.168.200.220 / 1901
# b'\xff\xd8\xff'
# From: 192.168.200.220 / 1901
# b'|SN'
# ||SN23030555|192.168.200.220|VEH_NorthEastern1|Vehicle_SH/SL/IVN/DWB|djBasis.exe, djJAUS_IVN.exe, djEtherMap.exe, DJ_LDR.EXE, djSharedLinkF.exe, GPS2RDDF.EXE, djMimic.exe, djPinger.exe, djDriveWB.exe|0|0|0|0|||01-01-2012|00:00:34|SharedLink,192.168.200.220:4000:4220;Cmd: Restart System,restart djBasis,7101;Cmd: Guideline dist,follow #,7101||
# From: 192.168.200.220 / 1901
# b'\xff\xd8\xff'
# From: 192.168.200.220 / 1901
# b'|SN'
# ||SN23030555|192.168.200.220|VEH_NorthEastern1|Vehicle_SH/SL/IVN/DWB|djBasis.exe, djJAUS_IVN.exe, djEtherMap.exe, DJ_LDR.EXE, djSharedLinkF.exe, GPS2RDDF.EXE, djMimic.exe, djPinger.exe, djDriveWB.exe|0|0|0|0|||01-01-2012|00:00:34|SharedLink,192.168.200.220:4000:4220;Cmd: Restart System,restart djBasis,7101;Cmd: Guideline dist,follow #,7101||
# From: 192.168.200.220 / 1901
# b'\xff\xd8\xff'
# From: 192.168.200.220 / 1901

# %%
broadcast_listener.stop()

# %%
def calcCheckSum(msg: str) -> str:
    check_sum = sum(ord(chr) for chr in msg) % 0x100
    # check_sum = sum % 0xff
    return f"{check_sum:X}"

def prepForSend(msg: str) -> str:
    return f"[{msg}{calcCheckSum(msg)}]"

# %%
# Had to give myself 192.168.200.x subnet alias as kairos is there and can't route to 192.168.0.x I guess
# Command I used was
# sudo ifconfig en0 alias 192.168.200.50 255.255.255.0

KAIROS_HOST = "192.168.200.220"

SHARED_LINK_OUTBOUND_PORT = 4000
SHARED_LINK_INBOUND_PORT = 4220

MY_HOST = "192.168.200.50"

declare_myIP_msg = f":BA|ELink|D0, SetIP, {MY_HOST}:{SHARED_LINK_INBOUND_PORT}, 4000|C"

enab_msgs = [
    ":BA|ELink|D0, outbound, on|C",
    ":BA|ELink|D0, inbound, on|C"
]

list_SVs_msgs = [
    ":BA|MUI|C",
    ":BA|MUO|C",
    ":BA|N0|T0|Qvideo_mux1|T0|Qveh_start|T0|Qveh_enable|T0|Qveh_motion|T2|Qjoy_steer|T0|Qveh_steer|T0|Qveh_brake|T0|Qveh_throttle|T0|Qveh_shift|T0|Qveh_clutch|C",
    ":BA|L0|T2|QAutoGpsHead|T2|QAutoGpsLat|T2|QAutoGpsLon|T2|QAutoGpsVel|T0|QAutoGpsReferences|T0|QAutoGpsQuality|T2|QAutoGpsStamp|T0|Qpause|T0|Qkey_on|T0|Qeng_enb|T0|Qpe7|T0|Qbbrake|T0|Qfbrake|T2|Qsteerang|T0|Qthrottle|Qsvp_enb_eng|T0|Qserialpck|T0|Qveh_gear|T0|Qveh_state|T0|Qveh_estop|T0|Qveh_obstacle|T2|Qvehicle_bat|T4|Qrun_composite|T4|QVehicleName|T0|QHealth_total|T0|Qrpm|T0|Qfuel|T2|Qsys_thd|C"
    ":BA|MW|C",
    ":BA|ML|C"
]

# Should respond with something like
# [:AB|N0|Rvideo_mux1|D0|Rveh_start|D0|Rveh_enable|D0|Rveh_motion|D0|Rjoy_steer|D0|Rveh_steer|D0|Rveh_brake|D100|Rveh_throttle|D0|Rveh_shift|D0|Rveh_clutch|D0|C92]
# Not sure if it'll also have that for the quires for KAIROS's outbound variables too 
# this might even be unnecessary and just used to confirm that it is getting the changes

term_msgs = [
    ":BA|ELink|D0, outbound, off|C",
    ":BA|ELink|D0, inbound, off|C"
]

ping_msg = ":BA|P0|C"
pong_msg = ":BA|G0|C"

teleop_start = ":BA|EServoPod|D0,TELEOP START|C"
teleop_stop = ":BA|EServoPod|D0,TELEOP STOP|C"

# %%
from collections import OrderedDict
from dataclasses import dataclass
from typing import Union

@dataclass
class SharedVariable:
    type: int  # 0=long, 2=double, 4=string
    value: Union[int, float, str, None] = None
    updated: bool = False

    def setValue(self, val):
        self.value = val
        self.updated = True

class SharedLink:
    def __init__(self):
        self._outbound_SVs = self._parse_sv_list(list_SVs_msgs[2])
        self._inbound_SVs = self._parse_sv_list(list_SVs_msgs[3])
        self._outbound_stream = UDPStream(SHARED_LINK_OUTBOUND_PORT, dest_host=KAIROS_HOST)
        self._inbound_stream = UDPStream(SHARED_LINK_INBOUND_PORT, on_recv=self._msg_parser)

        self._inbound_data_counter = 0

    def __del__(self):
        self._outbound_stream.__del__()
        self._inbound_stream.__del__()

    def stop(self):
        self._outbound_stream.stop()
        self._inbound_stream.stop()

    def _msg_parser(self, data_raw, addr):
        # was getting error that it couldn't decode xff, but it also wasn't 
        if data_raw[1:4] == b'\xff\xd8\xff':
            # setattr(img_widget, 'value', data_raw[1:])
            print("Seems to be a JPEG")
        else:
            data = data_raw.decode("utf-8")

            if data[:5] != "[:AB|":
                print("Data isn't in SharedLink form")
                print(data)
                return
            
            split_data = data[1:-1].split("|")

            # assume that checksum is always right because sent over UDP
            # assert calcCheckSum(data[1:-3]) == data[-3:-1]

            match split_data[1]:
                case "N0":        
                    match split_data[2][0]:
                        case "D":
                            self._apply_inbound_data(split_data[2:-1])
                        case "R":
                            print("Received R type:")
                            print(data)
                        case _:
                            print(f"Received N0 then {split_data[2]}")
                            print(data)
                case "P0":
                    # print("Received Ping Request")
                    self.sendMsg(pong_msg)
                case "G0":
                    print("Received Pong Message (ping ACK)")
                case _:
                    print(f"Received {split_data[1]} msg")
                
        
        # print(f"From: {addr[0]} / {addr[1]}")

    def _apply_inbound_data(self, data_values: list):
        """Apply a list of D field values to the inbound map in order."""
        assert len(self._inbound_SVs) == len(data_values)

        for (name, sv), value in zip(self._inbound_SVs.items(), data_values):
            assert value[0] == "D"
            value = value[1:]

            if value is not None and value != '':
                # Cast to correct type
                if sv.type == 0:
                    sv.value = int(value)
                elif sv.type == 2:
                    sv.value = float(value)
                elif sv.type == 4:
                    sv.value = str(value)
                sv.updated = False

        self._inbound_data_counter += 1
        if self._inbound_data_counter % 50 == 49:
            print(f"50 inbound data received: #{self._inbound_data_counter // 50}") 

    def _parse_sv_list(self, command: str) -> OrderedDict:
        """Parse a SharedLink list command into an ordered dict of SharedVariables."""
        result = OrderedDict()
        
        # Strip the framing and checksum
        # Remove leading/trailing whitespace and brackets
        inner = command.strip().lstrip(':')
        
        # Split on pipes
        fields = inner.split('|')
        
        current_type = 0  # default to long if no type specified
        for field in fields:
            if field.startswith('T'):
                # Type field - next variable will use this type
                try:
                    current_type = int(field[1:])
                except ValueError:
                    pass
            elif field.startswith('Q'):
                # Variable name
                name = field[1:]
                result[name] = SharedVariable(type=current_type)
                current_type = 0  # reset to default after each variable
        
        return result
    
    def printData(self, outbound=True, inbound=False):
        print("Outbound data:")
        for name, sv in self._outbound_SVs.items():
            print(f"{name}: type={sv.type}, value={sv.value}, updated={sv.updated}")

        print("\nInbound data:")
        for name, sv in self._inbound_SVs.items():
            print(f"{name}: type={sv.type}, value={sv.value}, updated={sv.updated}")
    
    def setData(self, name: str, value: Union[int, float, str]):
        assert name in self._outbound_SVs

        self._outbound_SVs[name].setValue(value)

    def sendData(self):
        msg = ":BA|N0|"
        for name, sv in self._outbound_SVs.items():
            msg += f"D{sv.value}|"
        msg += "C"
        self.sendMsg(msg)
        

    def sendMsg(self, msg: str):
        self._outbound_stream.send(prepForSend(msg).encode("utf-8"))

    def sendMsgs(self, msgs: list):
        for msg in msgs:
            self._outbound_stream.send(prepForSend(msg).encode("utf-8"))

# %%
talker.stop()

# %%
talker = SharedLink()
# Out:
# From: 192.168.200.220 / 4000
# Data: [rejected]
# From: 192.168.200.220 / 4000
# Data: [rejected]
# From: 192.168.200.220 / 4000
# Data: [rejected]
# From: 192.168.200.220 / 4000
# Data: [rejected]
# 50 inbound data received: #0
# From: 192.168.200.220 / 4000
# Data: [rejected]
# From: 192.168.200.220 / 4000
# Data: [rejected]
# From: 192.168.200.220 / 4000
# Data: [rejected]
# From: 192.168.200.220 / 4000
# Data: [rejected]
# From: 192.168.200.220 / 4000
# Data: [rejected]
# 50 inbound data received: #1
# From: 192.168.200.220 / 4000
# Data: [rejected]
# From: 192.168.200.220 / 4000
# Data: [rejected]
# From: 192.168.200.220 / 4000
# Data: [rejected]
# From: 192.168.200.220 / 4000
# Data: [rejected]
# From: 192.168.200.220 / 4000
# Data: [rejected]
# 50 inbound data received: #2
# From: 192.168.200.220 / 4000
# Data: [rejected]
# From: 192.168.200.220 / 4000
# Data: [rejected]
# From: 192.168.200.220 / 4000
# Data: [rejected]
# From: 192.168.200.220 / 4000
# Data: [rejected]
# From: 192.168.200.220 / 4000
# Data: [rejected]
# 50 inbound data received: #3
# From: 192.168.200.220 / 4000
# Data: [rejected]
# From: 192.168.200.220 / 4000
# Data: [rejected]
# From: 192.168.200.220 / 4000
# Data: [rejected]
# From: 192.168.200.220 / 4000
# Data: [rejected]
# From: 192.168.200.220 / 4000
# Data: [rejected]
# 50 inbound data received: #4
# From: 192.168.200.220 / 4000
# Data: [rejected]
# From: 192.168.200.220 / 4000
# Data: [rejected]
# From: 192.168.200.220 / 4000
# Data: [rejected]
# From: 192.168.200.220 / 4000
# Data: [rejected]
# 50 inbound data received: #5
# 50 inbound data received: #6
# 50 inbound data received: #7
# 50 inbound data received: #8
# Received Pong Message (ping ACK)
# 50 inbound data received: #9
# Received Pong Message (ping ACK)
# Received Pong Message (ping ACK)
# 50 inbound data received: #10
# 50 inbound data received: #11
# 50 inbound data received: #12
# 50 inbound data received: #13
# 50 inbound data received: #14
# 50 inbound data received: #15
# 50 inbound data received: #16
# 50 inbound data received: #17
# 50 inbound data received: #18
# 50 inbound data received: #19
# 50 inbound data received: #20
# 50 inbound data received: #21
# 50 inbound data received: #22
# 50 inbound data received: #23
# 50 inbound data received: #24
# 50 inbound data received: #25
# 50 inbound data received: #26
# 50 inbound data received: #27
# 50 inbound data received: #28
# 50 inbound data received: #29
# 50 inbound data received: #30
# 50 inbound data received: #31
# 50 inbound data received: #32
# 50 inbound data received: #33
# 50 inbound data received: #34
# 50 inbound data received: #35
# 50 inbound data received: #36
# 50 inbound data received: #37
# 50 inbound data received: #38
# 50 inbound data received: #39
# 50 inbound data received: #40
# 50 inbound data received: #41
# 50 inbound data received: #42
# 50 inbound data received: #43
# 50 inbound data received: #44
# 50 inbound data received: #45
# 50 inbound data received: #46
# 50 inbound data received: #47
# 50 inbound data received: #48
# 50 inbound data received: #49
# 50 inbound data received: #50
# 50 inbound data received: #51
# 50 inbound data received: #52
# 50 inbound data received: #53
# 50 inbound data received: #54
# 50 inbound data received: #55
# 50 inbound data received: #56
# 50 inbound data received: #57
# 50 inbound data received: #58
# 50 inbound data received: #59
# 50 inbound data received: #60
# 50 inbound data received: #61
# 50 inbound data received: #62
# 50 inbound data received: #63
# 50 inbound data received: #64
# 50 inbound data received: #65
# 50 inbound data received: #66
# 50 inbound data received: #67
# 50 inbound data received: #68
# 50 inbound data received: #69
# 50 inbound data received: #70
# 50 inbound data received: #71
# 50 inbound data received: #72
# 50 inbound data received: #73
# 50 inbound data received: #74
# 50 inbound data received: #75
# 50 inbound data received: #76
# 50 inbound data received: #77
# 50 inbound data received: #78
# 50 inbound data received: #79
# 50 inbound data received: #80
# 50 inbound data received: #81
# 50 inbound data received: #82
# 50 inbound data received: #83
# 50 inbound data received: #84
# 50 inbound data received: #85
# 50 inbound data received: #86
# 50 inbound data received: #87
# 50 inbound data received: #88
# 50 inbound data received: #89
# 50 inbound data received: #90
# 50 inbound data received: #91
# 50 inbound data received: #92
# 50 inbound data received: #93
# 50 inbound data received: #94
# 50 inbound data received: #95
# 50 inbound data received: #96
# 50 inbound data received: #97
# 50 inbound data received: #98
# 50 inbound data received: #99
# 50 inbound data received: #100
# 50 inbound data received: #101
# 50 inbound data received: #102
# 50 inbound data received: #103
# 50 inbound data received: #104
# 50 inbound data received: #105
# 50 inbound data received: #106
# 50 inbound data received: #107
# 50 inbound data received: #108
# 50 inbound data received: #109
# 50 inbound data received: #110
# 50 inbound data received: #111
# 50 inbound data received: #112
# 50 inbound data received: #113
# 50 inbound data received: #114
# 50 inbound data received: #115
# 50 inbound data received: #116
# 50 inbound data received: #117
# 50 inbound data received: #118
# 50 inbound data received: #119
# 50 inbound data received: #120
# 50 inbound data received: #121
# 50 inbound data received: #122
# 50 inbound data received: #123
# 50 inbound data received: #124
# 50 inbound data received: #125
# 50 inbound data received: #126
# 50 inbound data received: #127
# 50 inbound data received: #128
# 50 inbound data received: #129
# 50 inbound data received: #130
# 50 inbound data received: #131
# 50 inbound data received: #132
# 50 inbound data received: #133
# 50 inbound data received: #134
# 50 inbound data received: #135
# 50 inbound data received: #136
# 50 inbound data received: #137
# 50 inbound data received: #138
# 50 inbound data received: #139
# 50 inbound data received: #140
# 50 inbound data received: #141
# 50 inbound data received: #142
# 50 inbound data received: #143
# 50 inbound data received: #144
# 50 inbound data received: #145
# 50 inbound data received: #146
# 50 inbound data received: #147
# 50 inbound data received: #148
# 50 inbound data received: #149
# 50 inbound data received: #150
# 50 inbound data received: #151
# 50 inbound data received: #152
# 50 inbound data received: #153
# 50 inbound data received: #154
# 50 inbound data received: #155
# 50 inbound data received: #156
# 50 inbound data received: #157
# 50 inbound data received: #158
# 50 inbound data received: #159
# 50 inbound data received: #160
# 50 inbound data received: #161
# 50 inbound data received: #162
# 50 inbound data received: #163
# 50 inbound data received: #164
# 50 inbound data received: #165
# 50 inbound data received: #166
# 50 inbound data received: #167
# 50 inbound data received: #168
# 50 inbound data received: #169
# 50 inbound data received: #170
# 50 inbound data received: #171
# 50 inbound data received: #172
# 50 inbound data received: #173
# 50 inbound data received: #174
# 50 inbound data received: #175
# 50 inbound data received: #176
# 50 inbound data received: #177
# 50 inbound data received: #178
# 50 inbound data received: #179
# 50 inbound data received: #180
# 50 inbound data received: #181
# 50 inbound data received: #182
# 50 inbound data received: #183
# 50 inbound data received: #184
# 50 inbound data received: #185
# 50 inbound data received: #186
# 50 inbound data received: #187
# 50 inbound data received: #188
# 50 inbound data received: #189
# 50 inbound data received: #190
# 50 inbound data received: #191
# 50 inbound data received: #192
# 50 inbound data received: #193
# 50 inbound data received: #194
# 50 inbound data received: #195
# 50 inbound data received: #196
# 50 inbound data received: #197
# 50 inbound data received: #198
# 50 inbound data received: #199
# 50 inbound data received: #200
# 50 inbound data received: #201
# 50 inbound data received: #202
# 50 inbound data received: #203
# 50 inbound data received: #204
# 50 inbound data received: #205
# 50 inbound data received: #206
# 50 inbound data received: #207
# 50 inbound data received: #208
# 50 inbound data received: #209
# 50 inbound data received: #210
# 50 inbound data received: #211
# 50 inbound data received: #212
# 50 inbound data received: #213
# 50 inbound data received: #214
# 50 inbound data received: #215
# 50 inbound data received: #216
# 50 inbound data received: #217
# 50 inbound data received: #218
# 50 inbound data received: #219
# 50 inbound data received: #220
# 50 inbound data received: #221
# 50 inbound data received: #222
# 50 inbound data received: #223
# 50 inbound data received: #224
# 50 inbound data received: #225
# 50 inbound data received: #226
# 50 inbound data received: #227
# 50 inbound data received: #228
# 50 inbound data received: #229
# 50 inbound data received: #230
# 50 inbound data received: #231
# 50 inbound data received: #232
# 50 inbound data received: #233
# 50 inbound data received: #234
# 50 inbound data received: #235
# 50 inbound data received: #236
# 50 inbound data received: #237
# 50 inbound data received: #238
# 50 inbound data received: #239
# 50 inbound data received: #240
# 50 inbound data received: #241
# 50 inbound data received: #242
# 50 inbound data received: #243
# 50 inbound data received: #244
# 50 inbound data received: #245
# 50 inbound data received: #246
# 50 inbound data received: #247
# 50 inbound data received: #248
# 50 inbound data received: #249
# 50 inbound data received: #250
# 50 inbound data received: #251
# 50 inbound data received: #252
# 50 inbound data received: #253
# 50 inbound data received: #254
# 50 inbound data received: #255
# 50 inbound data received: #256
# 50 inbound data received: #257
# 50 inbound data received: #258
# 50 inbound data received: #259
# 50 inbound data received: #260
# 50 inbound data received: #261
# 50 inbound data received: #262
# 50 inbound data received: #263
# 50 inbound data received: #264
# 50 inbound data received: #265
# 50 inbound data received: #266
# 50 inbound data received: #267
# 50 inbound data received: #268
# 50 inbound data received: #269
# 50 inbound data received: #270
# 50 inbound data received: #271
# 50 inbound data received: #272
# 50 inbound data received: #273
# 50 inbound data received: #274
# 50 inbound data received: #275
# 50 inbound data received: #276
# 50 inbound data received: #277
# 50 inbound data received: #278
# 50 inbound data received: #279
# 50 inbound data received: #280
# 50 inbound data received: #281
# 50 inbound data received: #282
# 50 inbound data received: #283
# 50 inbound data received: #284
# 50 inbound data received: #285
# 50 inbound data received: #286
# 50 inbound data received: #287
# 50 inbound data received: #288
# 50 inbound data received: #289
# 50 inbound data received: #290
# 50 inbound data received: #291
# 50 inbound data received: #292
# 50 inbound data received: #293
# 50 inbound data received: #294
# 50 inbound data received: #295
# 50 inbound data received: #296
# 50 inbound data received: #297
# 50 inbound data received: #298
# 50 inbound data received: #299
# 50 inbound data received: #300
# 50 inbound data received: #301
# 50 inbound data received: #302
# 50 inbound data received: #303
# 50 inbound data received: #304
# 50 inbound data received: #305
# 50 inbound data received: #306
# 50 inbound data received: #307
# 50 inbound data received: #308
# 50 inbound data received: #309
# 50 inbound data received: #310
# 50 inbound data received: #311
# 50 inbound data received: #312
# 50 inbound data received: #313
# 50 inbound data received: #314
# 50 inbound data received: #315
# 50 inbound data received: #316
# 50 inbound data received: #317
# 50 inbound data received: #318
# 50 inbound data received: #319
# 50 inbound data received: #320
# 50 inbound data received: #321
# 50 inbound data received: #322
# 50 inbound data received: #323
# 50 inbound data received: #324
# 50 inbound data received: #325
# 50 inbound data received: #326
# 50 inbound data received: #327
# 50 inbound data received: #328
# 50 inbound data received: #329
# 50 inbound data received: #330
# 50 inbound data received: #331
# 50 inbound data received: #332
# 50 inbound data received: #333
# 50 inbound data received: #334
# 50 inbound data received: #335
# 50 inbound data received: #336
# 50 inbound data received: #337
# 50 inbound data received: #338
# 50 inbound data received: #339
# 50 inbound data received: #340
# 50 inbound data received: #341
# 50 inbound data received: #342
# 50 inbound data received: #343
# 50 inbound data received: #344
# 50 inbound data received: #345
# 50 inbound data received: #346
# 50 inbound data received: #347
# 50 inbound data received: #348
# 50 inbound data received: #349
# 50 inbound data received: #350
# 50 inbound data received: #351
# 50 inbound data received: #352
# 50 inbound data received: #353
# 50 inbound data received: #354
# 50 inbound data received: #355
# 50 inbound data received: #356
# 50 inbound data received: #357
# 50 inbound data received: #358
# 50 inbound data received: #359
# 50 inbound data received: #360
# 50 inbound data received: #361
# 50 inbound data received: #362
# 50 inbound data received: #363
# 50 inbound data received: #364
# 50 inbound data received: #365
# 50 inbound data received: #366
# 50 inbound data received: #367
# 50 inbound data received: #368
# 50 inbound data received: #369
# 50 inbound data received: #370
# 50 inbound data received: #371
# 50 inbound data received: #372
# 50 inbound data received: #373
# 50 inbound data received: #374
# 50 inbound data received: #375
# 50 inbound data received: #376
# 50 inbound data received: #377
# 50 inbound data received: #378
# 50 inbound data received: #379
# 50 inbound data received: #380
# 50 inbound data received: #381
# 50 inbound data received: #382
# 50 inbound data received: #383
# 50 inbound data received: #384
# 50 inbound data received: #385
# 50 inbound data received: #386
# 50 inbound data received: #387
# 50 inbound data received: #388
# 50 inbound data received: #389
# 50 inbound data received: #390
# 50 inbound data received: #391
# 50 inbound data received: #392
# 50 inbound data received: #393
# 50 inbound data received: #394
# 50 inbound data received: #395
# 50 inbound data received: #396
# 50 inbound data received: #397
# 50 inbound data received: #398
# 50 inbound data received: #399
# 50 inbound data received: #400
# 50 inbound data received: #401
# 50 inbound data received: #402
# 50 inbound data received: #403
# 50 inbound data received: #404
# 50 inbound data received: #405
# 50 inbound data received: #406
# 50 inbound data received: #407
# 50 inbound data received: #408
# 50 inbound data received: #409
# 50 inbound data received: #410
# 50 inbound data received: #411
# 50 inbound data received: #412
# 50 inbound data received: #413
# 50 inbound data received: #414
# 50 inbound data received: #415
# 50 inbound data received: #416
# 50 inbound data received: #417
# 50 inbound data received: #418
# 50 inbound data received: #419
# 50 inbound data received: #420
# 50 inbound data received: #421
# 50 inbound data received: #422
# 50 inbound data received: #423
# 50 inbound data received: #424
# 50 inbound data received: #425
# 50 inbound data received: #426
# 50 inbound data received: #427
# 50 inbound data received: #428
# 50 inbound data received: #429
# 50 inbound data received: #430
# 50 inbound data received: #431
# 50 inbound data received: #432
# 50 inbound data received: #433
# 50 inbound data received: #434
# 50 inbound data received: #435
# 50 inbound data received: #436
# 50 inbound data received: #437
# 50 inbound data received: #438
# 50 inbound data received: #439
# 50 inbound data received: #440
# 50 inbound data received: #441
# 50 inbound data received: #442
# 50 inbound data received: #443
# 50 inbound data received: #444
# 50 inbound data received: #445
# 50 inbound data received: #446
# 50 inbound data received: #447
# 50 inbound data received: #448
# 50 inbound data received: #449
# 50 inbound data received: #450
# 50 inbound data received: #451
# 50 inbound data received: #452
# 50 inbound data received: #453
# 50 inbound data received: #454

# %%
talker.setData("video_mux1", 0)
talker.setData("veh_start", 0)
####
talker.setData("veh_enable", 1)

talker.setData("veh_motion", 0)

#####
talker.setData("joy_steer", 0)

talker.setData("veh_steer", 0)

#####
talker.setData("veh_brake", 0)
talker.setData("veh_throttle", 100)

talker.setData("veh_shift", 0)
talker.setData("veh_clutch", 0)

# %%
talker.sendData()

# %%
# talker.sendMsg(declare_myIP_msg)
# talker.sendMsgs(enab_msgs)
# talker.sendMsgs(list_SVs_msgs)
# talker.sendMsg(list_SVs_msgs[2])
# talker.sendMsg(ping_msg)
# talker.sendMsg(teleop_start)
talker.sendMsgs(term_msgs)

# %%
talker.printData()
# Out:
# Outbound data:
# video_mux1: type=0, value=0, updated=True
# veh_start: type=0, value=0, updated=True
# veh_enable: type=0, value=1, updated=True
# veh_motion: type=0, value=0, updated=True
# joy_steer: type=2, value=0, updated=True
# veh_steer: type=0, value=0, updated=True
# veh_brake: type=0, value=0, updated=True
# veh_throttle: type=0, value=100, updated=True
# veh_shift: type=0, value=0, updated=True
# veh_clutch: type=0, value=0, updated=True
#
# Inbound data:
# AutoGpsHead: type=2, value=None, updated=False
# AutoGpsLat: type=2, value=0.0, updated=False
# AutoGpsLon: type=2, value=0.0, updated=False
# AutoGpsVel: type=2, value=0.0, updated=False
# AutoGpsReferences: type=0, value=0, updated=False
# AutoGpsQuality: type=0, value=0, updated=False
# AutoGpsStamp: type=2, value=6014.265, updated=False
# pause: type=0, value=0, updated=False
# key_on: type=0, value=1, updated=False
# eng_enb: type=0, value=1, updated=False
# pe7: type=0, value=1, updated=False
# bbrake: type=0, value=100, updated=False
# fbrake: type=0, value=0, updated=False
# steerang: type=2, value=0.0, updated=False
# throttle: type=0, value=0, updated=False
# svp_enb_eng: type=0, value=None, updated=False
